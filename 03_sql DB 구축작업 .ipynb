# %%
import pandas as pd
from sqlalchemy import create_engine



engine = create_engine("postgresql://postgres:67368279@localhost:5432/NutriBot")

df = pd.read_csv('/Users/gim-yujin/Desktop/pjt_personal_agent/데이터/데이터 파일/csv/supplement_rag_data_merged_with_reviews.csv')
df.to_sql(
    name='supplements',
    con=engine,
    schema='public',
    if_exists='append',  # 기존 테이블에 추가 ('replace'는 전체 덮어쓰기)
    index=False
)
# Out:
# 306

# %%
pd.read_sql('SELECT * FROM public.supplements LIMIT 30', engine)
# Out:
#      id                                              title  \
# 0     1            Phillip's, Laxative Caplets, 55 Caplets
# 1     2  Carlson, Kid's Vitamin C Gummies, Natural Oran...
# 2     3      NOW Foods, Glycine, Pure Powder, 1 lb (454 g)
# 3     4  Sun Chlorella, Chlorella Supplement, 200 mg, 3...
# 4     5  Flora, Certified Organic Elderberry + With Ech...
# 5     6  Zand, Echinacea Zinc, Very Cherry, 80 Throat L...
# 6    29         Jarrow Formulas, MK-7, 90 mcg, 90 Softgels
# 7   226  21st Century, Niacin, Prolonged Release, 250 m...
# 8     7  Life Extension, Standardized Cistanche, 30 Veg...
# 9     8  NutraChamps, L-Arginine, 60 Easy-to-Swallow Ve...
# 10    9  California Gold Nutrition, CurcuminUP, 30 Fish...
# 11   10                  Herb Pharm, Maca, 1 fl oz (30 ml)
# 12   11                  Carlson, Zinc, 15 mg, 250 Tablets
# 13   12  Teeccino, Organic Roasted Herbal Tea, Dandelio...
# 14   30  Emerald Laboratories, Thyroid Health, 60 Veget...
# 15   13  NOW Foods, Sports, B-12 Energy Boost Sticks, T...
# 16   14  Zarbee's, Black Elderberry Syrup with Real Eld...
# 17   15  Optimum Nutrition, ESSENTIAL AMIN.O. ENERGY, W...
# 18   16  Natural Factors, BioCoenzymated, B12, Methylco...
# 19   17  California Gold Nutrition, FOODS, Peanut & Dar...
# 20   18  Solgar, No. 7, Joint Support & Comfort, 30 Veg...
# 21   19  Ojio, Chlorella Spirulina, 50/50 Blend, 250 mg...
# 22   20  Quest Nutrition, Tortilla Style Protein Chips,...
# 23   21   NOW Foods, C-1000 Zinc Immune , 180 Veg Capsules
# 24   22  Nordic Naturals, Nordic Omega-3 Fishies, For A...
# 25   31  Frontier Co-Op, Slippery Elm Inner Bark, 16 oz...
# 26   23  Ovega-3, Vegan Omega-3, DHA + EPA, 500 mg, 60 ...
# 27   24  Citracal, Calcium Supplement, Slow Release 120...
# 28   25  Bluebonnet Nutrition, Liquid Calcium Magnesium...
# 29   26  ReserveAge Nutrition, Collagen Booster, 120 Ca...
#
#                                              category  \
# 0                                 Magnesium, Phillips
# 1        Ascorbic Acid, Carlson, Children's Vitamin C
# 2                                L-Glycine, NOW Foods
# 3                            Chlorella, Sun Chlorella
# 4         Elderberry Sambucus, Flora, Immune Formulas
# 5            Sore Throat & Cough Lozenges, Zand, Zinc
# 6                          Jarrow Formulas, Vitamin K
# 7                             21st Century, B3 Niacin
# 8              Herbs, Immune Formulas, Life Extension
# 9                             L-Arginine, NutraChamps
# 10  California Gold Nutrition, Fish Oil & Omegas (...
# 11                                   Herb Pharm, Maca
# 12                   Carlson, Common Cold & Flu, Zinc
# 13  Dandelion Tea, Herbal Coffee Alternative, Teec...
# 14  Emerald Laboratories, Herbal Formulas, Thyroid...
# 15                    B12, Energy Formulas, NOW Foods
# 16  Children's Herbs & Homeopathy, Elderberry Samb...
# 17               Amino Acid Blends, Optimum Nutrition
# 18                               B12, Natural Factors
# 19  California Gold Nutrition, Plant Based Protein...
# 20         Bone, Joint & Cartilage, Boswellia, Solgar
# 21                         Chlorella, Ojio, Spirulina
# 22                    Protein Snacks, Quest Nutrition
# 23                     Ascorbic Acid, NOW Foods, Zinc
# 24           Children's DHA & Omegas, Nordic Naturals
# 25           Frontier Co-Op, Herbal Tea, Slippery Elm
# 26                          Omega-3 Fish Oil, Ovega-3
# 27                   Calcium Plus Vitamin D, Citracal
# 28                      Bluebonnet Nutrition, Calcium
# 29         Collagen Supplements, Reserveage Nutrition
#
#                         brand  \
# 0                    Phillips
# 1                     Carlson
# 2                   NOW Foods
# 3               Sun Chlorella
# 4                       Flora
# 5                        Zand
# 6             Jarrow Formulas
# 7                21st Century
# 8              Life Extension
# 9                 NutraChamps
# 10  California Gold Nutrition
# 11                 Herb Pharm
# 12                    Carlson
# 13                   Teeccino
# 14       Emerald Laboratories
# 15                  NOW Foods
# 16                    Zarbees
# 17          Optimum Nutrition
# 18            Natural Factors
# 19  California Gold Nutrition
# 20                     Solgar
# 21                       Ojio
# 22            Quest Nutrition
# 23                  NOW Foods
# 24            Nordic Naturals
# 25             Frontier Co-Op
# 26                    Ovega-3
# 27                   Citracal
# 28       Bluebonnet Nutrition
# 29       Reserveage Nutrition
#
#                                      supplement_facts  \
# 0   [{"name": "Daily ValueMagnesium", "amount": 50...
# 1   [{"name": "Includes", "amount": 2.0, "unit": "...
# 2   [{"name": "about", "amount": 151.0, "unit": ""...
# 3   [{"name": "Total CarbohydrateLess than", "amou...
# 4   [{"name": "Daily ValueOrganic Black Elderberry...
# 5   [{"name": "Percent Daily Values are based on a...
# 6   [{"name": ")", "amount": 90.0, "unit": "mcg", ...
# 7                                                  []
# 8        [{"name": "to", "amount": 22.0, "unit": ""}]
# 9   [{"name": "30Amount Per ServingDaily ValueL-Ar...
# 10  [{"name": "Fish Oil Concentrate", "amount": 57...
# 11  [{"name": "Certified OrganicE Extraction rate"...
# 12  [{"name": "Daily Value   Calcium (from dicalci...
# 13  [{"name": "Includes", "amount": 0.0, "unit": "...
# 14  [{"name": "100 mg Percent Daily Value based on...
# 15  [{"name": "Total Carbohydrate", "amount": 4.0,...
# 16  [{"name": "40Total Carbohydrate", "amount": 5....
# 17  [{"name": "9 g (About", "amount": 2.0, "unit":...
# 18  [{"name": "dibencozide)", "amount": 3000.0, "u...
# 19  [{"name": "Includes", "amount": 3.0, "unit": "...
# 20  [{"name": "1 Extract (Curcuma longa) (equivale...
# 21  [{"name": "Spirulina (Spirulina platensis)3 gP...
# 22  [{"name": "Includes", "amount": 0.0, "unit": "...
# 23  [{"name": "Zinc (elemental) (from", "amount": ...
# 24  [{"name": "Amount Per Serving", "amount": 2.0,...
# 25  [{"name": "about", "amount": 349.0, "unit": ""...
# 26  [{"name": "0 g Added Sugars", "amount": 0.0, "...
# 27  [{"name": "Calcium", "amount": 1200.0, "unit":...
# 28  [{"name": "Includes", "amount": 1.0, "unit": "...
# 29  [{"name": "BlendJapanese Knotweed Extract (Pol...
#
#                                           description  \
# 0   Dietary SupplementStimulant FreeCramp FreeEasy...
# 1   Dietary SupplementIgen Non-GMO TestedImmune Su...
# 2   \nNeurotransmitter Support\nPromotes Restful S...
# 3   Pulverized Cell Wall by DYNO®-MillNon GMO Proj...
# 4   Gluten-Free + Vegan + No Added SugarUSDA Organ...
# 5   Lozenges that Work™Naturals5 mg Zinc Echinacea...
# 6   Most Active Form of Vitamin K2Supports Bone An...
# 7   Energy & Circulatory SupportVitamin Supplement...
# 8   Gluten FreeNon GMO LE CertifiedImmune Senescen...
# 9   Extra Strength Nitric Oxide BoosterSupport Ene...
# 10  California Gold Nutrition CurcuminUP™Omega-3 C...
# 11  Lepidium MeyeniiSystem RestorationReproductive...
# 12  Dietary SupplementImmune SupportAntioxidantSki...
# 13  Dandelion Blend3x More Herbs USDA Organic Preb...
# 14  The Additive-Free CompanyDoctor-FormulatedSens...
# 15  Energy Production10,000 mcg B-12On-The-Go Ener...
# 16  Immune Support Clinically Supported Ingredient...
# 17  Artificially FlavoredDietary SupplementSupport...
# 18  Dietary SupplementEnviroSimplex® Processed Pla...
# 19  California Gold Nutrition Peanut & Dark Chocol...
# 20  Increased FlexibilityIncreased MobilityShows I...
# 21   Dietary Supplement Kosher Ojio Chlorella-Spir...
# 22  19 g Protein Per Serving4 g Net Carbs* Per Ser...
# 23  Vitamin C, 1,000 mg  & Zinc, 15 mgSeasonal Sup...
# 24  300 mg Omega-3sChew Omega-3 Fishies Support No...
# 25  Member Owned Since 1976Ulmus RubraHerbal Suppl...
# 26  Plant-Based Omega-3500 mg Omega-3s>80% DHA + E...
# 27  Slo-Cal® TechnologySlowly and Continuously Rel...
# 28  Dietary SupplementMilk FreeKosher ParveGluten ...
# 29  #1 Collagen Capsule BrandWith Hyaluronic Acid ...
#
#                                                  tags  avg_rating  \
# 0           Daily ValueMagnesium, Magnesium, Phillips         4.5
# 1   Acid, Ascorbic, C, Carlson, Children's, Includ...         4.9
# 2   about, Amount Per Serving Daily Value Glycine ...         4.7
# 3         Chlorella, Sun, Total CarbohydrateLess than         4.8
# 4   Daily ValueOrganic Black Elderberry juice crys...         4.7
# 5   &, Cough, Lozenges, Percent Daily Values are b...         4.8
# 6                     ), Formulas, Jarrow, K, Vitamin         4.8
# 7                           21st, B3, Century, Niacin         4.6
# 8        Extension, Formulas, Herbs, Immune, Life, to         4.5
# 9   1250 mgGrape Seed Extract (Vitis vinifera) (St...         4.9
# 10  &, (EPA, California, Curcumin, DHA), Fish, Fis...         4.7
# 11  Certified OrganicE Extraction rate, Herb, Maca...         4.2
# 12  &, Carlson, Cold, Common, Daily Value   Calciu...         4.8
# 13  Alternative, Coffee, Dandelion, Herbal, Includ...         4.7
# 14  100 mg Percent Daily Value based on a, Emerald...         4.7
# 15  B12, Energy, Foods, Formulas, NOW, Total Carbo...         4.6
# 16  &, 40Total Carbohydrate, Children's, Elderberr...         4.9
# 17  5 gCaffeine100 mgGreen Tea Leaf Extract50 mgGr...         4.7
# 18                B12, dibencozide), Factors, Natural         4.8
# 19  Bars, Based, California, Gold, Includes, Nutri...         4.7
# 20  &, 1 Extract (Curcuma longa) (equivalent to, B...         4.7
# 21  Chlorella, Ojio, Spirulina, Spirulina (Spiruli...         4.7
# 22        Includes, Nutrition, Protein, Quest, Snacks         4.6
# 23  Acid, Ascorbic, Foods, NOW, Zinc, Zinc (elemen...         4.9
# 24  &, 1Daily Value (DV) for children, 2Daily Valu...         4.8
# 25  3 g Percent Daily Values are based on a, about...         4.7
# 26  0 g Added Sugars, 1 gOmega-3 fatty acids (from...         4.8
# 27                Calcium, Citracal, D, Plus, Vitamin         4.8
# 28           Bluebonnet, Calcium, Includes, Nutrition         4.8
# 29  BlendJapanese Knotweed Extract (Polygonum cusp...         4.5
#
#     reviews_count
# 0              70
# 1             337
# 2            2640
# 3             106
# 4             288
# 5             754
# 6             175
# 7             764
# 8             202
# 9              58
# 10           4480
# 11             55
# 12           1480
# 13            175
# 14            513
# 15             60
# 16            482
# 17            235
# 18            444
# 19           5293
# 20           3476
# 21            182
# 22           2528
# 23           2005
# 24           5462
# 25            182
# 26            913
# 27            440
# 28            442
# 29            246
